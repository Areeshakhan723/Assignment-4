# %% [markdown]
# # **Problem Statement**
# This program counts the number of times each number appears in a list. It uses a dictionary to keep track of the information.
#
# An example run of the program looks like this:
#
# Enter a number: 3 Enter a number: 4 Enter a number: 3 Enter a number: 6 Enter a number: 4 Enter a number: 3 Enter a number: 12 Enter a number: 3 appears 3 times. 4 appears 2 times. 6 appears 1 times. 12 appears 1 times.

# %%
def get_user_numbers():
    """
    Create an empty list.
    Ask the user to input numbers and store them in a list.
    Once they enter a blank line, break out of the loop and return the list.
    """
    my_list = []
    while True:

      userInput = input("Enter a number: ")

       # If the user enters a blank line, break out of the loop and stop asking for input
      if userInput == "":
        print("Goode bye!")
        break

      # convert the user input to an integer and add it to the list
      num = int(userInput)
      my_list.append(num)

    return my_list

def count_nums(num_lst):
    """
    Create an empty dictionary.
    Loop over the list of numbers.
    If the number is not in the dictionary, add it as a key with a value of 1.
    If the number is in the dictionary, increment its value by 1.
    """

    num_dict = {}

    for num in num_lst:
      if num not in num_dict:
        num_dict[num] = 1
      else:
        num_dict[num] += 1

    return num_dict

def print_counts(num_dict):
    """
    Loop over the dictionary and print out each key and its value.
    """

    for num in num_dict:
      print(f"{num} appears {num_dict[num]} times.")


def main():
  """
   Main function to execute the program.

    1. Calls `get_user_numbers()` to collect numbers from the user.
    2. Calls `count_nums()` to count occurrences of each number.
    3. Calls `print_counts()` to display the frequency of each number.
  """
  user_numbers = get_user_numbers()  # Store user input list
  num_counts = count_nums(user_numbers)  # Get the number frequency
  print_counts(num_counts)  # Print the results


if __name__ == '__main__':
    main()
# Out:
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# Enter a number: 3
# Enter a number: 3
# Enter a number: 2
# Enter a number: 1
# Enter a number:
# Goode bye!
# 2 appears 2 times.
# 3 appears 3 times.
# 4 appears 1 times.
# 1 appears 1 times.
