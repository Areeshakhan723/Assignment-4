# %% [markdown]
# # **Problem Statement**
# Implement the following function which takes in 3 integers as parameters:
#
# def in_range(n, low, high) """ Returns True if n is between low and high, inclusive. high is guaranteed to be greater than low. """

# %%
def in_range(n, low, high):
  """
  Returns True if n is between low and high, inclusive.
  high is guaranteed to be greater than low.
  """

  if n >= low and n <= high:
    return True

  return False

def main():
  low = 10
  high = 20
  user_input = input("Enter a number (or press enter to quit): ")

  while user_input != "":
    n = int(user_input)  # convert string to int
    if in_range(n, low, high):
      print(f"{n} is in range [{low}, {high}]")
    else:
      print(f"{n} is NOT in range [{low}, {high}]")
    user_input = input("Enter a number (or press enter to quit): ")


if __name__ == '__main__':
    main()
# Out:
# Enter a number (or press enter to quit): 15
# 15 is in range [10, 20]
# Enter a number (or press enter to quit): 4
# 4 is NOT in range [10, 20]
# Enter a number (or press enter to quit):
